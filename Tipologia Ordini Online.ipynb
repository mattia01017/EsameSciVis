# %%
# %matplotlib inline

import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.constants import golden

# %%
ordini = pd.read_csv('Tipo di Acquisti e Ordini.csv', sep=',')

# %%
pd.set_option('display.max_rows', ordini.shape[0]+1)
ordini = ordini[["Tipo dato", "Sesso", "Classe di età", "TIME", "Value"]]
ordini
# Out:
#                                         Tipo dato    Sesso  Classe di età  \
# 0                             prodotti alimentari   maschi     20-24 anni
# 1                             prodotti alimentari   maschi     20-24 anni
# 2                             prodotti alimentari   maschi     20-24 anni
# 3                             prodotti alimentari   maschi     20-24 anni
# 4                             prodotti alimentari   maschi     20-24 anni
# 5                             prodotti alimentari   maschi     20-24 anni
# 6                             prodotti alimentari   maschi     20-24 anni
# 7                             prodotti alimentari   maschi     20-24 anni
# 8                             prodotti alimentari   maschi     20-24 anni
# 9                             prodotti alimentari   maschi     20-24 anni
# 10                            prodotti alimentari   maschi     20-24 anni
# 11                            prodotti alimentari   maschi     20-24 anni
# ...

# %%
#Tipologie di Acquisti

df_tipologieacquisti = ordini[((ordini["Sesso"]=='totale') & (ordini["Classe di età"]=="14 anni e più"))]
df_tipologieacquisti = df_tipologieacquisti.groupby("Tipo dato").mean()
df_tipologieacquisti = df_tipologieacquisti.drop(columns=["TIME"])
df_tipologieacquisti = df_tipologieacquisti.drop(["altro", "altre spese di viaggio per vacanze"])
df_tipologieacquisti.sort_values(by=['Value'], ascending=False, inplace=True)
df_tipologieacquisti
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_20792\3510595399.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_tipologieacquisti = df_tipologieacquisti.groupby("Tipo dato").mean()
#                                                  Value
# Tipo dato
# abiti, articoli sportivi                     30.693333
# pernottamenti per vacanze                    23.833333
# articoli per la casa                         21.526667
# attrezzature elettroniche                    20.093333
# biglietti per spettacoli                     18.926667
# film, musica                                 15.500000
# libri (inclusi e-book)                       11.820000
# hardware per computer                        10.273333
# servizi di telecomunicazione                  7.786667
# ...

# %%
Valori_Medi = df_tipologieacquisti["Value"].values.tolist()

# %%
categorie = df_tipologieacquisti.index.values.tolist()
categorie
# Out:
# ['abiti, articoli sportivi',
#  'pernottamenti per vacanze',
#  'articoli per la casa',
#  'attrezzature elettroniche',
#  'biglietti per spettacoli',
#  'film, musica',
#  'libri (inclusi e-book)',
#  'hardware per computer',
#  'servizi di telecomunicazione',
#  'software per computer e/o aggiornamenti',
#  'prodotti alimentari',
#  'videogiochi e/o loro aggiornamenti',
#  'azioni, servizi finanziari e/o assicurativi',
#  'giornali, riviste',
#  'materiale per la formazione a distanza',
#  'farmaci',
#  'biglietti per lotterie o scommesse']

# %%
#Tipologie di Acquisti
labels = categorie

plt.rc('figure', figsize=(10.0, 5.0))
fig, ax = plt.subplots()
width = 0.35 
plt.grid()
ax.bar(labels, Valori_Medi, width, label='Tipologie di Acquisti', alpha = 0.6, color = 'forestgreen')

plt.xticks(rotation='vertical')
ax.set_ylabel('% Persone')
ax.set_title('Tipologie di Acquisti')
plt.show()

# %%
plt.rc('figure', figsize=(11.0, 10.0))
fig, ax = plt.subplots()
y_pos = np.arange(len(categorie))
performance = Valori_Medi
width = 0.40 
ax.barh(y_pos, performance, width, align='center', color = 'forestgreen', alpha=0.6)
ax.set_yticks(y_pos, labels=categorie)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Percentuale Acquisto annuo')
ax.set_title('Tipologie di Prodotti')
plt.grid()
plt.show()
