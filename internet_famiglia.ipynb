# %% [markdown]
# # Situazione in Italia

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

data = pd.read_csv("data/famiglie_e_accesso_ad_internet.csv")
data
# Out:
#      ITTER107        Territorio TIPO_DATO_SDS_ICT  \
# 0          IT            Italia       FAM_INT_YES
# 1          IT            Italia       FAM_INT_YES
# 2          IT            Italia       FAM_INT_YES
# 3          IT            Italia       FAM_INT_YES
# 4          IT            Italia       FAM_INT_YES
# ...       ...               ...               ...
# 3803        9  50.001 ab. e più        FAM_NO_OTH
# 3804        9  50.001 ab. e più        FAM_NO_OTH
# 3805        9  50.001 ab. e più        FAM_NO_OTH
# 3806        9  50.001 ab. e più        FAM_NO_OTH
# 3807        9  50.001 ab. e più        FAM_NO_OTH
#
#                                               Tipo dato  TIME  \
# 0     famiglie che dispongono di accesso a Internet ...  2005
# 1     famiglie che dispongono di accesso a Internet ...  2006
# 2     famiglie che dispongono di accesso a Internet ...  2007
# 3     famiglie che dispongono di accesso a Internet ...  2008
# 4     famiglie che dispongono di accesso a Internet ...  2009
# ...                                                 ...   ...
# 3803                                              altro  2016
# 3804                                              altro  2017
# 3805                                              altro  2018
# 3806                                              altro  2019
# 3807                                              altro  2020
#
#       Seleziona periodo  Value  Flag Codes  Flags
# 0                  2005   34.5         NaN    NaN
# 1                  2006   35.6         NaN    NaN
# 2                  2007   38.8         NaN    NaN
# 3                  2008   42.0         NaN    NaN
# 4                  2009   47.3         NaN    NaN
# ...                 ...    ...         ...    ...
# 3803               2016    7.4         NaN    NaN
# 3804               2017    7.8         NaN    NaN
# 3805               2018    7.9         NaN    NaN
# 3806               2019    8.1         NaN    NaN
# 3807               2020    7.1         NaN    NaN
#
# [3808 rows x 9 columns]

# %%
zones = ['Nord-ovest', 'Nord-est', 'Centro', 'Sud', 'Isole']

datazsyes = data.loc[list(map(lambda x: x in zones, data['Territorio'])) & 
    (data['TIPO_DATO_SDS_ICT'] == 'FAM_INT_YES')]
datazsyes
# Out:
#      ITTER107  Territorio TIPO_DATO_SDS_ICT  \
# 112       ITC  Nord-ovest       FAM_INT_YES
# 113       ITC  Nord-ovest       FAM_INT_YES
# 114       ITC  Nord-ovest       FAM_INT_YES
# 115       ITC  Nord-ovest       FAM_INT_YES
# 116       ITC  Nord-ovest       FAM_INT_YES
# ...       ...         ...               ...
# 2811      ITG       Isole       FAM_INT_YES
# 2812      ITG       Isole       FAM_INT_YES
# 2813      ITG       Isole       FAM_INT_YES
# 2814      ITG       Isole       FAM_INT_YES
# 2815      ITG       Isole       FAM_INT_YES
#
#                                               Tipo dato  TIME  \
# 112   famiglie che dispongono di accesso a Internet ...  2005
# 113   famiglie che dispongono di accesso a Internet ...  2006
# 114   famiglie che dispongono di accesso a Internet ...  2007
# 115   famiglie che dispongono di accesso a Internet ...  2008
# 116   famiglie che dispongono di accesso a Internet ...  2009
# ...                                                 ...   ...
# 2811  famiglie che dispongono di accesso a Internet ...  2016
# 2812  famiglie che dispongono di accesso a Internet ...  2017
# 2813  famiglie che dispongono di accesso a Internet ...  2018
# 2814  famiglie che dispongono di accesso a Internet ...  2019
# 2815  famiglie che dispongono di accesso a Internet ...  2020
#
#       Seleziona periodo  Value  Flag Codes  Flags
# 112                2005   36.2         NaN    NaN
# 113                2006   38.4         NaN    NaN
# 114                2007   41.8         NaN    NaN
# 115                2008   44.5         NaN    NaN
# 116                2009   48.4         NaN    NaN
# ...                 ...    ...         ...    ...
# 2811               2016   63.6         NaN    NaN
# 2812               2017   67.9         NaN    NaN
# 2813               2018   69.5         NaN    NaN
# 2814               2019   71.3         NaN    NaN
# 2815               2020   73.4         NaN    NaN
#
# [80 rows x 9 columns]

# %%
years = list(set(datazsyes['TIME'].values))
years.sort()

pop = pd.read_csv('data/popolazione.csv')
pop = pop.loc[
    list(map(lambda x: x in zones or x == 'Italia', pop['Territorio'])) & 
    (pop['Sesso'] == 'totale') &
    (pop['Età'] == 'totale')
]
pop
# Out:
#       ITTER107  Territorio TIPO_DATO15 Tipo di indicatore demografico  \
# 40604       IT      Italia         JAN      popolazione al 1º gennaio
# 40607      ITC  Nord-ovest         JAN      popolazione al 1º gennaio
# 40694      ITD    Nord-est         JAN      popolazione al 1º gennaio
# 40781      ITE      Centro         JAN      popolazione al 1º gennaio
# 40859      ITF         Sud         JAN      popolazione al 1º gennaio
# 40949      ITG       Isole         JAN      popolazione al 1º gennaio
#
#        SEXISTAT1   Sesso   ETA1     Età  STATCIV2 Stato civile  TIME  \
# 40604          9  totale  TOTAL  totale        99       totale  2022
# 40607          9  totale  TOTAL  totale        99       totale  2022
# 40694          9  totale  TOTAL  totale        99       totale  2022
# 40781          9  totale  TOTAL  totale        99       totale  2022
# 40859          9  totale  TOTAL  totale        99       totale  2022
# 40949          9  totale  TOTAL  totale        99       totale  2022
#
#        Seleziona periodo     Value Flag Codes         Flags
# 40604               2022  58983122          e  dato stimato
# 40607               2022  15848100          e  dato stimato
# 40694               2022  11561676          e  dato stimato
# 40781               2022  11740836          e  dato stimato
# 40859               2022  13451861          e  dato stimato
# 40949               2022   6380649          e  dato stimato

# %%
datazsyesn = datazsyes.copy()

for z in zones:
    m = interp1d(
        [0,100], 
        [0,100*pop.loc[pop['Territorio'] == z, 'Value'].iloc[0] / pop.loc[pop['Territorio'] == 'Italia', 'Value'].iloc[0]]
    )
    datazsyesn.loc[datazsyesn['Territorio'] == z, 'Value'] = m(
        datazsyesn.loc[datazsyesn['Territorio'] == z, 'Value']
    )

f, ax = plt.subplots()
f.set_figheight(10)
f.set_figwidth(18)

ax.set_yticks(years)
ax.invert_yaxis()
ax.set_xlabel("% famiglie con Internet in casa")
ax.set_ylabel("Anno")
offsets = [0] * len(years)
for z in zones:
    xd = datazsyesn.loc[datazsyesn['Territorio'] == z, 'Value']
    yd = datazsyesn.loc[datazsyesn['Territorio'] == z, 'TIME']
    ax.barh(yd, xd, left=offsets, label=z)
    for i in range(len(years)):
        offsets[i] += xd.iloc[i]
ax.legend()
plt.show()

# %%
f, ax = plt.subplots()

f.set_figheight(8)
f.set_figwidth(15)

datazsyes = datazsyes.sort_values('TIME')
ax.set_xlabel("% famiglie con Internet in casa")
ax.set_ylabel("Anno")

for z in zones:
    ax.plot(years, datazsyes.loc[datazsyes['Territorio'] == z, 'Value'], label=z)
ax.legend()
ax.grid(visible=True, linestyle="--")
plt.show()

# %% [markdown]
# # Tipo di connessione

# %%
ctdat = pd.read_csv('data/famiglie_e_tipo_di_connessione.csv')
ctdatnaz = ctdat.loc[ctdat['Territorio'] == 'Italia']

f, ax = plt.subplots()
f.set_figheight(10)
f.set_figwidth(18)

types = list(set(ctdatnaz['Tipo dato'].values))
colors = ['salmon', 'olive', 'maroon', 'teal']

for t, c in zip(types, colors):
    xd = ctdatnaz.loc[ctdatnaz['Tipo dato'] == t, 'TIME']
    yd = ctdatnaz.loc[ctdatnaz['Tipo dato'] == t, 'Value']
    ax.plot(xd, yd, label=t.capitalize(), marker='o', color=c)
ax.legend()
ax.grid(visible=True)
plt.show()

# %%
ctdatzon = ctdat.loc[list(map(lambda x: x in zones, ctdat['Territorio']))]

f, axs = plt.subplots(len(types)//2, len(types)//2)
f.set_figheight(10)
f.set_figwidth(18)

for i, t in enumerate(types):
    ax = axs[i//2, i%2]
    ax.set_title(t.capitalize())
    ax.set_ylim(0, 90)
    for z in zones:
        xd = ctdatzon.loc[(ctdatzon['Tipo dato'] == t) & (ctdatzon['Territorio'] == z), 'TIME']
        yd = ctdatzon.loc[(ctdatzon['Tipo dato'] == t) & (ctdatzon['Territorio'] == z), 'Value']
        ax.plot(xd, yd, label=z)
    ax.legend()
    ax.grid(visible=True)

# %% [markdown]
# # Tipo di famiglia

# %%
famdat = pd.read_csv('data/tipo_famiglia_accesso_a_internet.csv')
famdat = famdat.loc[famdat['TIPO_DATO_SDS_ICT'] == 'FAM_INT_YES']
famdat
# Out:
#     TIPO_DATO_SDS_ICT                                          Tipo dato  \
# 0         FAM_INT_YES  famiglie che dispongono di accesso a Internet ...
# 1         FAM_INT_YES  famiglie che dispongono di accesso a Internet ...
# 2         FAM_INT_YES  famiglie che dispongono di accesso a Internet ...
# 3         FAM_INT_YES  famiglie che dispongono di accesso a Internet ...
# 4         FAM_INT_YES  famiglie che dispongono di accesso a Internet ...
# ..                ...                                                ...
# 479       FAM_INT_YES  famiglie che dispongono di accesso a Internet ...
# 480       FAM_INT_YES  famiglie che dispongono di accesso a Internet ...
# 481       FAM_INT_YES  famiglie che dispongono di accesso a Internet ...
# 482       FAM_INT_YES  famiglie che dispongono di accesso a Internet ...
# 483       FAM_INT_YES  famiglie che dispongono di accesso a Internet ...
#
#     TIP_FAM Tipologia familiare  TIME  Seleziona periodo  Value  Flag Codes  \
# 0        HH     totale famiglie  2005               2005   34.5         NaN
# 1        HH     totale famiglie  2006               2006   35.6         NaN
# 2        HH     totale famiglie  2007               2007   38.8         NaN
# 3        HH     totale famiglie  2008               2008   42.0         NaN
# 4        HH     totale famiglie  2009               2009   47.3         NaN
# ..      ...                 ...   ...                ...    ...         ...
# 479  OTHER3     altre tipologie  2016               2016   81.1         NaN
# 480  OTHER3     altre tipologie  2017               2017   83.3         NaN
# 481  OTHER3     altre tipologie  2018               2018   87.0         NaN
# 482  OTHER3     altre tipologie  2019               2019   87.1         NaN
# 483  OTHER3     altre tipologie  2020               2020   90.4         NaN
#
#      Flags
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 479    NaN
# 480    NaN
# 481    NaN
# 482    NaN
# 483    NaN
#
# [64 rows x 9 columns]

# %%
types = list(set(famdat['Tipologia familiare'].values))
types.remove('totale famiglie')
types.sort()

years = list(set(famdat['TIME'].values))
years.sort()

famdat = famdat.sort_values('TIME')

f, ax = plt.subplots()

f.set_figheight(8)
f.set_figwidth(18)

dim = len(types)
w = .6
dimw = w / dim

colors = ['pink', 'grey', 'lightgreen']

for i,t in enumerate(types):
    ax.bar(
        list(map(lambda x: x + i*dimw, years)),
        famdat.loc[famdat['Tipologia familiare'] == t, 'Value'],
        dimw, label=t.capitalize(), color=colors[i]
    )
ax.legend()
ax.set_xlabel("Anno")
ax.set_ylabel("% famiglie con internet")
ax.set_xticks(list(map(lambda x: x+dimw, years)), labels=years)
plt.plot()
# Out:
# []

# %% [markdown]
# # Non utilizzatori di internet (percentuale)

# %%
datanaz = data.loc[
    (data['Territorio'] == 'Italia'),
    ['Value', 'Tipo dato', 'TIPO_DATO_SDS_ICT', 'TIME']
]
datanaz

no = datanaz.loc[datanaz['TIPO_DATO_SDS_ICT'] != 'FAM_INT_YES']
no = no.sort_values('TIME')

yes = datanaz.loc[datanaz['TIPO_DATO_SDS_ICT'] == 'FAM_INT_YES']

years = list(set(datanaz['TIME'].values))
years.sort()
types = list(set(datanaz['Tipo dato'].values))
for i in range(len(types)):
    if types[i] == 'altro':
        types[i], types[len(types)-1] = types[len(types)-1], types[i]

yes_str = "famiglie che dispongono di accesso a Internet da casa"

types_noyes = types.copy()
types_noyes.remove(yes_str)

f, axs = plt.subplots(len(types_noyes)//4, 4)
f.set_figheight(10)
f.set_figwidth(20)

colors = ['purple', 'sienna', 'blue', 'gold', 
    'chocolate', 'lime', 'grey', 'turquoise']

for i, t in enumerate(types_noyes):
    ax = axs[i//4, i % 4]
    ax.set_ylim(0, 65)
    ax.plot(
        no.loc[no['Tipo dato'] == t, 'TIME'],
        no.loc[no['Tipo dato'] == t, 'Value'],
        label=t, marker='o', color=colors[i]
    )
    ax.set_xticks([years[i] for i in range(0, len(years), 3)])
    ax.grid(visible=True, linestyle="--")
    ax.set_title(t.capitalize())


plt.show()

# %%
no = no[['Value', 'Tipo dato', 'TIME']]
print()


for y in years:
    m = interp1d(
        [0,100], 
        [0, 100-yes.loc[yes['TIME'] == y, 'Value'].iloc[0]]
    )
    no.loc[(no['Tipo dato'] != yes_str) & (no['TIME'] == y), 'Value'] = m(
        no.loc[(no['Tipo dato'] != yes_str) & (no['TIME'] == y), 'Value']
    )
no
# Out:
#        Value                                          Tipo dato  TIME
# 16    7.7290                   accede a Internet da altro luogo  2005
# 40    6.4845  alto costo degli strumenti necessari per conne...  2005
# 64   20.4360                          nessuno sa usare internet  2005
# 76    1.3100                       motivi di privacy, sicurezza  2005
# 28   26.4620            internet non è utile,non è interessante  2005
# ..       ...                                                ...   ...
# 51    1.3650  alto costo degli strumenti necessari per conne...  2020
# 39    5.3340            internet non è utile,non è interessante  2020
# 27    1.5960                   accede a Internet da altro luogo  2020
# 99    0.3570  connessione a banda larga non disponibile nell...  2020
# 111   1.0920                                              altro  2020
#
# [96 rows x 3 columns]

# %%
f, ax = plt.subplots()
f.set_figheight(10)
f.set_figwidth(18)

ax.set_xlabel("Anno")
ax.set_ylabel("% famiglie")

for i, t in enumerate(types_noyes):
    yd = no.loc[no['Tipo dato'] == t, 'Value']
    xd = no.loc[no['Tipo dato'] == t, 'TIME']
    
    if sum(yd) != 0:
        ax.plot(xd, yd, label=t.capitalize(), marker='o', color=colors[i])

ax.grid(visible=True, linestyle="--")
ax.legend()
plt.show()
