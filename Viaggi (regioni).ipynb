# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
data = pd.read_csv('Attività_regioni.csv')
zones = ['Nord-ovest', 'Nord-est', 'Centro', 'Sud', 'Isole']
years=data['TIME'].unique()

data = data.loc[list(map(lambda x: x in zones, data['Territorio']))]
data = data[data['Tipo dato']=='usare servizi relativi a viaggi o soggiorni']
data
# Out:
#      ITTER107  Territorio TIPO_DATO_SDS_ICT  \
# 320       ITC  Nord-ovest            IUHOLS
# 321       ITC  Nord-ovest            IUHOLS
# 322       ITC  Nord-ovest            IUHOLS
# 323       ITC  Nord-ovest            IUHOLS
# 324       ITC  Nord-ovest            IUHOLS
# ...       ...         ...               ...
# 7243      ITG       Isole            IUHOLS
# 7244      ITG       Isole            IUHOLS
# 7245      ITG       Isole            IUHOLS
# 7246      ITG       Isole            IUHOLS
# 7247      ITG       Isole            IUHOLS
#
#                                         Tipo dato  TIME  Seleziona periodo  \
# 320   usare servizi relativi a viaggi o soggiorni  2005               2005
# 321   usare servizi relativi a viaggi o soggiorni  2006               2006
# 322   usare servizi relativi a viaggi o soggiorni  2007               2007
# 323   usare servizi relativi a viaggi o soggiorni  2008               2008
# 324   usare servizi relativi a viaggi o soggiorni  2009               2009
# ...                                           ...   ...                ...
# 7243  usare servizi relativi a viaggi o soggiorni  2016               2016
# 7244  usare servizi relativi a viaggi o soggiorni  2017               2017
# 7245  usare servizi relativi a viaggi o soggiorni  2018               2018
# 7246  usare servizi relativi a viaggi o soggiorni  2019               2019
# 7247  usare servizi relativi a viaggi o soggiorni  2020               2020
#
#       Value  Flag Codes  Flags
# 320    42.0         NaN    NaN
# 321    42.5         NaN    NaN
# 322    45.2         NaN    NaN
# 323    47.4         NaN    NaN
# 324    52.3         NaN    NaN
# ...     ...         ...    ...
# 7243   27.7         NaN    NaN
# 7244   27.2         NaN    NaN
# 7245   24.5         NaN    NaN
# 7246   27.2         NaN    NaN
# 7247    0.0         NaN    NaN
#
# [80 rows x 9 columns]

# %%
valori1 = [42. , 42.5, 45.2, 47.4, 52.3, 48.6, 54.8, 43.7, 44.7, 41.2, 39.8, 39.5, 38.9, 40.6, 40.2, 50.2]
valori2 = [41.9, 41.2, 47. , 44.8, 48.8, 46.6, 49.1, 42.1, 43.9, 41.2, 35.7, 39.6, 38.4, 39.9, 39.1, 49.1]
valori3 = [41.7, 41.1, 45.9, 45.9, 50.7, 49.9, 52.6, 43.1, 44.1, 45.2, 37.6, 38. , 36.6, 37.3, 35.1, 45.1]
valori4 = [30.8, 31.1, 37.6, 35.8, 41.4, 38.1, 40.5, 34.9, 34.4, 29.7, 25.9, 27.7, 25.3, 26.6, 29.1, 45.1]
valori5 = [30.4, 32.6, 35.4, 35.2, 43.5, 35.6, 44.7, 34.3, 29.9, 27.8, 28.9, 27.7, 27.2, 24.5, 27.2, 43.2]

# %%
fig, ax = plt.subplots()

fig.set_figheight(8)
fig.set_figwidth(15)

ax.plot(years, valori1, label='Nord-ovest')
ax.plot(years, valori2, label='Nord-est')
ax.plot(years, valori3, label='Centro')
ax.plot(years, valori4, label='Sud')
ax.plot(years, valori5, label='Isole')

ax.set_xlabel('Anni')
ax.set_ylabel('% utenti che ')
    
ax.legend()
plt.show()
