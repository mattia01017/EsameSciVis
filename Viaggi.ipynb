# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
dataSet = pd.read_csv('Attivita_svolte_su _internet.csv')
dataSet = dataSet[dataSet['Classe di età']!='6 anni e più']
dataSet
# Out:
#      TIPO_DATO_SDS_ICT                                          Tipo dato  \
# 594           FINDGOOD            cercare informazioni su merci e servizi
# 595           FINDGOOD            cercare informazioni su merci e servizi
# 596           FINDGOOD            cercare informazioni su merci e servizi
# 597           FINDGOOD            cercare informazioni su merci e servizi
# 598           FINDGOOD            cercare informazioni su merci e servizi
# ...                ...                                                ...
# 7717             CLOUD  usare servizi di archiviazione su Internet per...
# 7718             CLOUD  usare servizi di archiviazione su Internet per...
# 7719             CLOUD  usare servizi di archiviazione su Internet per...
# 7720             CLOUD  usare servizi di archiviazione su Internet per...
# 7721             CLOUD  usare servizi di archiviazione su Internet per...
#
#       SEXISTAT1   Sesso    ETA1 Classe di età  TIME  Seleziona periodo  Value  \
# ...

# %%
viaggi = dataSet[dataSet['Tipo dato']=='usare servizi relativi a viaggi o soggiorni']
viaggi = viaggi[viaggi['TIME']!=2020]

viaggi = viaggi[viaggi['Sesso']=='totale']

valori1 = [2.7, 2.3, 2. , 0.7, 1. , 0.6, 1.6, 0.7, 0. , 0. , 0.]
valori2 = [7.6, 11. ,  5.1,  7.1,  5.8,  4.7,  4.5,  4.1,  5. ,  5.6, 5.8]
valori3 = [18.1, 22.7, 15.3, 18.8, 15.8, 14.6, 11. , 13.7, 14.7, 16.6, 18]
valori4 = [38.6, 46.6, 33.2, 35.7, 33.7, 31.3, 28.9, 33.3, 38. , 35.1, 45.1]
valori5 = [52.4, 56.7, 48.1, 49.5, 42.5, 40. , 40.3, 42.1, 47.6, 46.9, 56.9]
valori6 = [57.2, 61.7, 52.8, 49. , 49.6, 44.1, 45.9, 44.6, 47.6, 48.1, 58.1]
valori7 = [52.7, 56.4, 46.8, 47.1, 45.5, 38.9, 42.5, 41.9, 43.6, 43.1, 50.1]
valori8 = [48.4, 49.2, 42.2, 45.1, 37.7, 36.9, 37.7, 33.1, 33.3, 32.7, 40.7]
valori9 = [45.6, 57.8, 38.8, 41.7, 40.9, 37.2, 36.5, 31.1, 29.3, 30.1, 37.1]
valori10 = [38. , 34. , 30.9, 37. , 34. , 25.4, 25.7, 21.4, 16.9, 21.3, 27.3]

year = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
population = {
    '6-10 anni': valori1,
    '11-14 anni': valori2,
    '15-17 anni': valori3,
    '18-19 anni': valori4,
    '20-24 anni': valori5,
    '25-34 anni': valori6,
    '35-54 anni': valori7,
    '55-64 anni': valori8,
    '65-74 anni': valori9,
    '75 anni e più': valori10,
}

fig, ax = plt.subplots()

fig.set_figheight(8)
fig.set_figwidth(15)

ax.stackplot(year, population.values(),
             labels=population.keys(), alpha=1)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
ax.set_title('Usare servizi relativi a viaggi o soggiorni ')
ax.set_xlabel('Year')
ax.set_ylabel('Valori')

plt.show()

# %%
viaggi75['Value'].values
# Out:
# array([38. , 34. , 30.9, 37. , 34. , 25.4, 25.7, 21.4, 16.9, 21.3])

# %%
valori1 = [2.7, 2.3, 2. , 0.7, 1. , 0.6, 1.6, 0.7, 0. , 0. , 0.]
valori2 = [7.6, 11. ,  5.1,  7.1,  5.8,  4.7,  4.5,  4.1,  5. ,  5.6, 5.8]
valori3 = [18.1, 22.7, 15.3, 18.8, 15.8, 14.6, 11. , 13.7, 14.7, 16.6, 18]
valori4 = [38.6, 46.6, 33.2, 35.7, 33.7, 31.3, 28.9, 33.3, 38. , 35.1, 45.1]
valori5 = [52.4, 56.7, 48.1, 49.5, 42.5, 40. , 40.3, 42.1, 47.6, 46.9, 56.9]
valori6 = [57.2, 61.7, 52.8, 49. , 49.6, 44.1, 45.9, 44.6, 47.6, 48.1, 58.1]
valori7 = [52.7, 56.4, 46.8, 47.1, 45.5, 38.9, 42.5, 41.9, 43.6, 43.1, 50.1]
valori8 = [48.4, 49.2, 42.2, 45.1, 37.7, 36.9, 37.7, 33.1, 33.3, 32.7, 40.7]
valori9 = [45.6, 57.8, 38.8, 41.7, 40.9, 37.2, 36.5, 31.1, 29.3, 30.1, 37.1]
valori10 = [38. , 34. , 30.9, 37. , 34. , 25.4, 25.7, 21.4, 16.9, 21.3, 27.3]
