# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
dataSet = pd.read_csv('Attività svolte su internet.csv')
dataSet = dataSet[dataSet['Classe di età']!='6 anni e più']
dataSet = dataSet[dataSet['Sesso']!='totale']
dataSet = dataSet[dataSet['Tipo dato']=='vendere merci o servizi (es. aste online, eBay)']
dataSetm = dataSet[dataSet['Sesso']=='femmine']
dataSetm = dataSetm[dataSetm['TIME']==2020]

# %%
labels = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
valoriMaschi = [7.775000000000001, 12.183333333333332, 13.19166666666667, 13.541666666666666, 12.741666666666665, 11.924999999999999, 8.825000000000001, 9.5, 9.375, 9.791666666666666, 10.808333333333335]
valoriFemmine = [3.0500000000000007, 5.541666666666667, 6.716666666666666, 7.725000000000001, 7.4333333333333345, 6.2, 3.9416666666666664, 5.249999999999999, 5.391666666666667, 5.05, 6.999999999999999]
width = 0.5      # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()
fig.set_figheight(8)
fig.set_figwidth(12)

ax.bar(labels, valoriMaschi, width, label='Maschi')
ax.bar(labels, valoriFemmine, width, bottom=valoriMaschi, label='Femmine')

ax.set_ylim(0, 50)

ax.set_xlabel('Anni')
ax.set_ylabel('% utenti che utilizzano servizi per vendere prodotti')
ax.set_title('Confronto maschi/femmine - Vendita prodotti')
ax.legend()

plt.show()

# %%
dataSet = pd.read_csv('Attività svolte su internet.csv')
dataSet = dataSet[dataSet['Classe di età']!='6 anni e più']
dataSet = dataSet[dataSet['Sesso']=='totale']
dataSet = dataSet[dataSet['Tipo dato']=='vendere merci o servizi (es. aste online, eBay)']
dataSet
# Out:
#      TIPO_DATO_SDS_ICT                                        Tipo dato  \
# 1166            IUSELL  vendere merci o servizi (es. aste online, eBay)
# 1167            IUSELL  vendere merci o servizi (es. aste online, eBay)
# 1168            IUSELL  vendere merci o servizi (es. aste online, eBay)
# 1169            IUSELL  vendere merci o servizi (es. aste online, eBay)
# 1170            IUSELL  vendere merci o servizi (es. aste online, eBay)
# ...                ...                                              ...
# 7706            IUSELL  vendere merci o servizi (es. aste online, eBay)
# 7707            IUSELL  vendere merci o servizi (es. aste online, eBay)
# 7708            IUSELL  vendere merci o servizi (es. aste online, eBay)
# 7709            IUSELL  vendere merci o servizi (es. aste online, eBay)
# 7710            IUSELL  vendere merci o servizi (es. aste online, eBay)
#
#       SEXISTAT1   Sesso    ETA1 Classe di età  TIME  Seleziona periodo  Value  \
# ...

# %%
labels = ['6-10 anni', '11-14 anni', '15-17 anni', '18-19 anni', '20-24 anni', '25-34 anni', '35-44 anni', '45-54 anni', '55-59 anni', '60-64 anni', '65-74 anni', '75 anni e più']
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

fig, axs = plt.subplots(len(labels)//4, 4)
fig.set_figheight(15)
fig.set_figwidth(25)

for i, l in enumerate(labels):
        ax = axs[i//4, i%4]
        ax.set_ylim(0, 100)
        ax.bar(
                dataSet.loc[dataSet['Classe di età'] == l, 'TIME'],
                dataSet.loc[dataSet['Classe di età'] == l, 'Value'],
                label = l
        )
        ax.set_xticks([years[i] for i in range(0, len(years), 2)])
        ax.set_title(l.capitalize())

plt.show()
