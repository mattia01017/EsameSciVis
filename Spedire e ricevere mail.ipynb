# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
dataSet = pd.read_csv('Attività svolte su internet.csv')
dataSet = dataSet[dataSet['Classe di età']!='6 anni e più']
dataSet = dataSet[dataSet['Tipo dato']=='spedire o ricevere e-mail']
dataSet = dataSet[dataSet['Sesso']=='totale']
dataSet
# Out:
#      TIPO_DATO_SDS_ICT                  Tipo dato  SEXISTAT1   Sesso    ETA1  \
# 1056              IUEM  spedire o ricevere e-mail          9  totale  Y15-17
# 1057              IUEM  spedire o ricevere e-mail          9  totale  Y15-17
# 1058              IUEM  spedire o ricevere e-mail          9  totale  Y15-17
# 1059              IUEM  spedire o ricevere e-mail          9  totale  Y15-17
# 1060              IUEM  spedire o ricevere e-mail          9  totale  Y15-17
# ...                ...                        ...        ...     ...     ...
# 7596              IUEM  spedire o ricevere e-mail          9  totale  Y11-14
# 7597              IUEM  spedire o ricevere e-mail          9  totale  Y11-14
# 7598              IUEM  spedire o ricevere e-mail          9  totale  Y11-14
# 7599              IUEM  spedire o ricevere e-mail          9  totale  Y11-14
# 7600              IUEM  spedire o ricevere e-mail          9  totale  Y11-14
#
# ...

# %%
dataSet[dataSet['TIME']==2010]
# Out:
#      TIPO_DATO_SDS_ICT                  Tipo dato  SEXISTAT1   Sesso    ETA1  \
# 1056              IUEM  spedire o ricevere e-mail          9  totale  Y15-17
# 1650              IUEM  spedire o ricevere e-mail          9  totale  Y20-24
# 2244              IUEM  spedire o ricevere e-mail          9  totale  Y25-34
# 2838              IUEM  spedire o ricevere e-mail          9  totale  Y35-44
# 3432              IUEM  spedire o ricevere e-mail          9  totale  Y45-54
# 4026              IUEM  spedire o ricevere e-mail          9  totale  Y55-59
# 4620              IUEM  spedire o ricevere e-mail          9  totale  Y60-64
# 5214              IUEM  spedire o ricevere e-mail          9  totale  Y65-74
# 5808              IUEM  spedire o ricevere e-mail          9  totale  Y_GE75
# 6402              IUEM  spedire o ricevere e-mail          9  totale  Y18-19
# 6996              IUEM  spedire o ricevere e-mail          9  totale   Y6-10
# ...

# %%
labels = ['6-10 anni', '11-14 anni', '15-17 anni', '18-19 anni', '20-24 anni', '25-34 anni', '35-44 anni', '45-54 anni', '55-59 anni', '60-64 anni', '65-74 anni', '75 anni e più']
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

fig, axs = plt.subplots(len(labels)//4, 4)
fig.set_figheight(15)
fig.set_figwidth(25)

for i, l in enumerate(labels):
        ax = axs[i//4, i%4]
        ax.set_ylim(0, 100)
        ax.plot(
                dataSet.loc[dataSet['Classe di età'] == l, 'TIME'],
                dataSet.loc[dataSet['Classe di età'] == l, 'Value'],
                label = l, marker = 'o'
        )
        ax.set_xticks([years[i] for i in range(0, len(years), 2)])
        ax.set_title(l.capitalize())
        ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe610 = ['6-10 anni']
data = dataSet.loc[list(map(lambda x: x in classe610, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data['TIME'].values
valori = data['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='6-10 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe1114 = ['11-14 anni']
data2 = dataSet.loc[list(map(lambda x: x in classe1114, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data2['TIME'].values
valori = data2['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='11-14 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe1517 = ['15-17 anni']
data3 = dataSet.loc[list(map(lambda x: x in classe1517, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data3['TIME'].values
valori = data3['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='15-17 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe1819 = ['18-19 anni']
data4 = dataSet.loc[list(map(lambda x: x in classe1819, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data4['TIME'].values
valori = data4['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='18-19 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe2024 = ['20-24 anni']
data5 = dataSet.loc[list(map(lambda x: x in classe2024, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data5['TIME'].values
valori = data5['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='20-24 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe2534 = ['25-34 anni']
data6 = dataSet.loc[list(map(lambda x: x in classe2534, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data6['TIME'].values
valori = data6['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='25-34 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe3544 = ['35-44 anni']
data7 = dataSet.loc[list(map(lambda x: x in classe3544, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data7['TIME'].values
valori = data7['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='35-44 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe4554 = ['45-54 anni']
data8 = dataSet.loc[list(map(lambda x: x in classe4554, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data8['TIME'].values
valori = data8['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='45-54 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe5559 = ['55-59 anni']
data9 = dataSet.loc[list(map(lambda x: x in classe5559, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data9['TIME'].values
valori = data9['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='55-59 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe6064 = ['60-64 anni']
data10 = dataSet.loc[list(map(lambda x: x in classe6064, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data10['TIME'].values
valori = data10['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='60-64 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe6574 = ['65-74 anni']
data11 = dataSet.loc[list(map(lambda x: x in classe6574, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data11['TIME'].values
valori = data11['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='65-74 anni')
ax.grid(visible=True, linestyle="--")

plt.show()

# %%
classe75 = ['75 anni e più']
data12 = dataSet.loc[list(map(lambda x: x in classe75, dataSet['Classe di età'])) & (dataSet['Tipo dato'] == 'spedire o ricevere e-mail') & (dataSet['Sesso'] == 'totale')]

anno = data12['TIME'].values
valori = data12['Value'].values
fig, ax = plt.subplots()
ax.set_ylim(0,100)
ax.plot(anno, valori, marker='o')

ax.set(xlabel = 'Anno', ylabel='Valori', title='75 anni e più')
ax.grid(visible=True, linestyle="--")

plt.show()
