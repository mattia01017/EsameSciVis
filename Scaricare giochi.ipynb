# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
dataSet = pd.read_csv('Attività svolte su internet.csv')
dataSet = dataSet[dataSet['Classe di età']!='6 anni e più']

# %%
dataSet = dataSet[dataSet['Tipo dato']=='giocare o scaricare giochi, immagini, film, musica']
dataSet = dataSet[dataSet['Sesso']=='totale']
dataSet1 = dataSet[dataSet['TIME']==2010]
dataSet2 = dataSet[dataSet['TIME']==2019]

dataSet1 = dataSet1.sort_values('Classe di età')
dataSet2 = dataSet2.sort_values('Classe di età')

valori2010 = [71.6, 71.0, 72.0, 67.2, 61.6, 44.5, 29.5, 23.9, 18.7, 18.7, 16.2, 20.7]
valori2020 = [75.8, 78.9, 78.6, 75.1, 72.5, 58.9, 48.9, 38.9, 30.8, 27.4, 25.5, 22.8]

labels = ['6-10 anni', '10-14 anni', '15-17 anni', '18-19 anni', '20-24 anni', '25-34 anni', '35-44 anni', '45-54 anni', '55-59 anni', '60-64 anni', '65-74 anni', '75 anni e più']
valori2010 = [71.6, 71.0, 72.0, 67.2, 61.6, 44.5, 29.5, 23.9, 18.7, 18.7, 16.2, 20.7]
valori2020 = [75.8, 78.9, 78.6, 75.1, 72.5, 58.9, 48.9, 38.9, 30.8, 27.4, 25.5, 22.8]

x = np.arange(len(labels))  # the label locations
width = 0.4  # the width of the bars

fig, ax = plt.subplots()
fig.set_figheight(8)
fig.set_figwidth(12)

plt.xticks(rotation=90)
rects1 = ax.bar(x - width/2, valori2010, width, label='2010')
rects2 = ax.bar(x + width/2, valori2020, width, label='2020')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Classi di età')
ax.set_ylabel('Valori [%]')
ax.set_title('Confronto tra 2010 e 2020')
ax.set_xticks(x, labels)
ax.legend()

#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
