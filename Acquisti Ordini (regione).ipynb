# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
data = pd.read_csv('Attività_regioni.csv')
data
# Out:
#      ITTER107        Territorio TIPO_DATO_SDS_ICT  \
# 0          IT            Italia          FINDGOOD
# 1          IT            Italia          FINDGOOD
# 2          IT            Italia          FINDGOOD
# 3          IT            Italia          FINDGOOD
# 4          IT            Italia          FINDGOOD
# ...       ...               ...               ...
# 9787        9  50.001 ab. e più             CLOUD
# 9788        9  50.001 ab. e più             CLOUD
# 9789        9  50.001 ab. e più             CLOUD
# 9790        9  50.001 ab. e più             CLOUD
# 9791        9  50.001 ab. e più             CLOUD
#
#                                               Tipo dato  TIME  \
# 0               cercare informazioni su merci e servizi  2005
# 1               cercare informazioni su merci e servizi  2006
# 2               cercare informazioni su merci e servizi  2007
# 3               cercare informazioni su merci e servizi  2008
# 4               cercare informazioni su merci e servizi  2009
# ...                                                 ...   ...
# 9787  usare servizi di archiviazione su Internet per...  2016
# 9788  usare servizi di archiviazione su Internet per...  2017
# 9789  usare servizi di archiviazione su Internet per...  2018
# 9790  usare servizi di archiviazione su Internet per...  2019
# 9791  usare servizi di archiviazione su Internet per...  2020
#
#       Seleziona periodo  Value  Flag Codes  Flags
# 0                  2005   59.1         NaN    NaN
# 1                  2006   60.0         NaN    NaN
# 2                  2007   64.8         NaN    NaN
# 3                  2008   66.3         NaN    NaN
# 4                  2009   64.5         NaN    NaN
# ...                 ...    ...         ...    ...
# 9787               2016   26.7         NaN    NaN
# 9788               2017   29.0         NaN    NaN
# 9789               2018   29.7         NaN    NaN
# 9790               2019   30.7         NaN    NaN
# 9791               2020   37.4         NaN    NaN
#
# [9792 rows x 9 columns]

# %%
dataSet[dataSet[]]

# %%
zones = ['Nord-ovest', 'Nord-est', 'Centro', 'Sud', 'Isole']

data = data.loc[list(map(lambda x: x in zones, data['Territorio']))]
data
# Out:
#      ITTER107  Territorio TIPO_DATO_SDS_ICT  \
# 288       ITC  Nord-ovest          FINDGOOD
# 289       ITC  Nord-ovest          FINDGOOD
# 290       ITC  Nord-ovest          FINDGOOD
# 291       ITC  Nord-ovest          FINDGOOD
# 292       ITC  Nord-ovest          FINDGOOD
# ...       ...         ...               ...
# 7483      ITG       Isole             CLOUD
# 7484      ITG       Isole             CLOUD
# 7485      ITG       Isole             CLOUD
# 7486      ITG       Isole             CLOUD
# 7487      ITG       Isole             CLOUD
#
#                                               Tipo dato  TIME  \
# 288             cercare informazioni su merci e servizi  2005
# 289             cercare informazioni su merci e servizi  2006
# 290             cercare informazioni su merci e servizi  2007
# 291             cercare informazioni su merci e servizi  2008
# 292             cercare informazioni su merci e servizi  2009
# ...                                                 ...   ...
# 7483  usare servizi di archiviazione su Internet per...  2016
# 7484  usare servizi di archiviazione su Internet per...  2017
# 7485  usare servizi di archiviazione su Internet per...  2018
# 7486  usare servizi di archiviazione su Internet per...  2019
# 7487  usare servizi di archiviazione su Internet per...  2020
#
#       Seleziona periodo  Value  Flag Codes  Flags
# 288                2005   62.7         NaN    NaN
# 289                2006   64.5         NaN    NaN
# 290                2007   68.4         NaN    NaN
# 291                2008   71.2         NaN    NaN
# 292                2009   69.4         NaN    NaN
# ...                 ...    ...         ...    ...
# 7483               2016   23.4         NaN    NaN
# 7484               2017   28.3         NaN    NaN
# 7485               2018   25.3         NaN    NaN
# 7486               2019   26.4         NaN    NaN
# 7487               2020   32.1         NaN    NaN
#
# [1440 rows x 9 columns]
